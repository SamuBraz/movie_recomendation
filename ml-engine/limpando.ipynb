# %%
import  pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
###criando df para trabalho

df_movies = pd.read_csv('ml-latest-small/movies.csv')

df_tags = pd.read_csv("ml-latest-small/tags.csv")


movies_tags = df_movies.merge(df_tags, on='movieId')



df_tags = df_tags.drop(columns=['userId', 'timestamp'])


df_tags_normalize = df_tags.groupby('movieId')['tag'].agg('|'.join).reset_index()


movies_tags = df_movies.merge(df_tags_normalize, on='movieId', how='left')


movies_tags.to_csv('data/cbf_df.csv', index=False)

# %%
df_movies_gen = df_movies['genres']


df_movies_gen.to_csv('generos.csv')

# %%
colunas_para_combinar = [col for col in movies_tags.columns if col != 'movieId']

print(type(movies_tags))
movies_tags["geral"] = movies_tags[colunas_para_combinar].apply(
    lambda row: ' '.join(row.values.astype(str)), 
    axis=1
)

movies_tags["geral"] = movies_tags["geral"].apply(lambda x: x.replace(",", " "))
movies_tags["geral"] = movies_tags["geral"].apply(lambda x: x.replace("|", " "))
movies_tags["geral"] = movies_tags["geral"].apply(lambda x: x.replace("(", " "))
movies_tags["geral"] = movies_tags["geral"].apply(lambda x: x.replace(")", " "))
movies_tags.to_csv('data/cbf_df.csv', index=False)
# Out:
#       movieId                          titulo_movie_lens  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9703   193581  Black Butler: Book of the Atlantic (2017)
# 9704   193583               No Game No Life: Zero (2017)
# 9705   193585                               Flint (2017)
# 9706   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9707   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  \
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9703              Action|Animation|Comedy|Fantasy
# 9704                     Animation|Comedy|Fantasy
# 9705                                        Drama
# 9706                             Action|Animation
# 9707                                       Comedy
#
#                                                tag
# 0                                  pixar|pixar|fun
# 1     fantasy|magic board game|Robin Williams|game
# 2                                        moldy|old
# 3                                              NaN
# 4                                 pregnancy|remake
# ...                                            ...
# 9703                                           NaN
# 9704                                           NaN
# 9705                                           NaN
# 9706                                           NaN
# 9707                                           NaN
#
# [9708 rows x 4 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 colunas_para_combinar = [col for col in movies_tags.columns if col != 'movieId']
#       3 print(movies_tags)
# ----> 4 movies_tags["geral"] = movies_tags[colunas_para_combinar].apply(
#       5     lambda row: ' '.join(row.values.astype(str)),
#       6     axis=1
#       7 )
#       9 movies_tags["geral"] = movies_tags["geral"].apply(lambda x: x.replace(",", " "))
#      10 movies_tags["geral"] = movies_tags["geral"].apply(lambda x: x.replace("|", " "))
#
# File ~/movie_recomendation/.venv/lib/python3.12/site-packages/pandas/core/frame.py:12419, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12405         raise ValueError(f"Unknown engine '{engine}'")
#   12407     op = frame_apply(
#   12408         self,
#   12409         func=func,
#    (...)  12417         kwargs=kwargs,
#   12418     )
# > 12419     return op.apply().__finalize__(self, method="apply")
#   12420 elif hasattr(engine, "__pandas_udf__"):
#   12421     if result_type is not None:
#
# File ~/movie_recomendation/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
#    1013     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# -> 1015 return self.apply_standard()
#
# File ~/movie_recomendation/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1167, in FrameApply.apply_standard(self)
#    1165 def apply_standard(self):
#    1166     if self.engine == "python":
# -> 1167         results, res_index = self.apply_series_generator()
#    1168     else:
#    1169         results, res_index = self.apply_series_numba()
#
# File ~/movie_recomendation/.venv/lib/python3.12/site-packages/pandas/core/apply.py:1183, in FrameApply.apply_series_generator(self)
#    1180 results = {}
#    1182 for i, v in enumerate(series_gen):
# -> 1183     results[i] = self.func(v, *self.args, **self.kwargs)
#    1184     if isinstance(results[i], ABCSeries):
#    1185         # If we have a view on v, we need to make a copy because
#    1186         #  series_generator will swap out the underlying data
#    1187         results[i] = results[i].copy(deep=False)
#
# Cell In[15], line 5, in <lambda>(row)
#       1 colunas_para_combinar = [col for col in movies_tags.columns if col != 'movieId']
#       3 print(movies_tags)
#       4 movies_tags["geral"] = movies_tags[colunas_para_combinar].apply(
# ----> 5     lambda row: ' '.join(row.values.astype(str)),
#       6     axis=1
#       7 )
#       9 movies_tags["geral"] = movies_tags["geral"].apply(lambda x: x.replace(",", " "))
#      10 movies_tags["geral"] = movies_tags["geral"].apply(lambda x: x.replace("|", " "))
#
# TypeError: sequence item 2: expected str instance, float found

# %%
lista_compilado = movies_tags["geral"].tolist()

print(lista_compilado)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/movie_recomendation/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'geral'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 lista_compilado = movies_tags["geral"].tolist()
#       3 print(lista_compilado)
#
# File ~/movie_recomendation/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~/movie_recomendation/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'geral'

# %%
cvec = CountVectorizer(stop_words='english', min_df=3, max_df=0.5, ngram_range=(1,2))

sf = cvec.fit_transform(lista_compilado)


print(sf)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 83503 stored elements and shape (9708, 3511)>
#   Coords	Values
#   (0, 3269)	1
#   (0, 3101)	1
#   (0, 384)	1
#   (0, 688)	1
#   (0, 758)	1
#   (0, 1100)	1
#   (0, 1172)	1
#   (0, 1577)	1
#   (0, 2633)	2
#   (0, 1704)	1
#   (0, 3270)	1
#   (0, 386)	1
#   (0, 689)	1
#   (0, 759)	1
#   (0, 1101)	1
#   (0, 1182)	1
#   (1, 384)	1
#   (1, 688)	1
#   (1, 1100)	1
#   (1, 1577)	2
#   (1, 386)	1
#   (1, 2256)	1
#   (1, 1719)	2
#   (1, 2805)	1
#   (1, 3447)	1
#   :	:
#   (9704, 2185)	1
#   (9704, 760)	1
#   (9704, 3506)	1
#   (9704, 627)	1
#   (9704, 630)	1
#   (9705, 1421)	1
#   (9705, 1452)	1
#   (9705, 1655)	1
#   (9705, 627)	1
#   (9705, 634)	1
#   (9706, 758)	1
#   (9706, 662)	1
#   (9706, 1320)	1
#   (9706, 1397)	1
#   (9706, 787)	1
#   (9706, 664)	1
#   (9706, 767)	1
#   (9706, 637)	1
#   (9706, 638)	1
#   (9707, 1172)	1
#   (9707, 1189)	1
#   (9707, 343)	1
#   (9707, 347)	1
#   (9707, 745)	1
#   (9707, 2861)	1

# %%
cvec = CountVectorizer(stop_words='english', min_df=3, max_df=0.5, ngram_range=(1,2))

sf = cvec.fit_transform(lista_compilado)


print(sf)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 83503 stored elements and shape (9708, 3511)>
#   Coords	Values
#   (0, 3269)	1
#   (0, 3101)	1
#   (0, 384)	1
#   (0, 688)	1
#   (0, 758)	1
#   (0, 1100)	1
#   (0, 1172)	1
#   (0, 1577)	1
#   (0, 2633)	2
#   (0, 1704)	1
#   (0, 3270)	1
#   (0, 386)	1
#   (0, 689)	1
#   (0, 759)	1
#   (0, 1101)	1
#   (0, 1182)	1
#   (1, 384)	1
#   (1, 688)	1
#   (1, 1100)	1
#   (1, 1577)	2
#   (1, 386)	1
#   (1, 2256)	1
#   (1, 1719)	2
#   (1, 2805)	1
#   (1, 3447)	1
#   :	:
#   (9704, 2185)	1
#   (9704, 760)	1
#   (9704, 3506)	1
#   (9704, 627)	1
#   (9704, 630)	1
#   (9705, 1421)	1
#   (9705, 1452)	1
#   (9705, 1655)	1
#   (9705, 627)	1
#   (9705, 634)	1
#   (9706, 758)	1
#   (9706, 662)	1
#   (9706, 1320)	1
#   (9706, 1397)	1
#   (9706, 787)	1
#   (9706, 664)	1
#   (9706, 767)	1
#   (9706, 637)	1
#   (9706, 638)	1
#   (9707, 1172)	1
#   (9707, 1189)	1
#   (9707, 343)	1
#   (9707, 347)	1
#   (9707, 745)	1
#   (9707, 2861)	1

# %%
transformer = TfidfTransformer()
tfidf_matrix = transformer.fit_transform(sf)
print(tfidf_matrix)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 83503 stored elements and shape (9708, 3511)>
#   Coords	Values
#   (0, 384)	0.1696971105999758
#   (0, 386)	0.26346725896581374
#   (0, 688)	0.11122524597504889
#   (0, 689)	0.17099909397461893
#   (0, 758)	0.1380237065003913
#   (0, 759)	0.16380176892238968
#   (0, 1100)	0.1333601998799516
#   (0, 1101)	0.15717683756554396
#   (0, 1172)	0.07142460231298155
#   (0, 1182)	0.1729653085842593
#   (0, 1577)	0.12912929159863187
#   (0, 1704)	0.2888840506884501
#   (0, 2633)	0.6286016848221728
#   (0, 3101)	0.20711236765060115
#   (0, 3269)	0.30761535170212156
#   (0, 3270)	0.3224832217485037
#   (1, 384)	0.1657779748863166
#   (1, 386)	0.2573825122052937
#   (1, 688)	0.1086565114089731
#   (1, 690)	0.18426228430843292
#   (1, 1100)	0.13028026103902282
#   (1, 1105)	0.20008953778135385
#   (1, 1577)	0.25229413021872515
#   (1, 1581)	0.3070420997491083
#   (1, 1584)	0.31503550795454455
#   :	:
#   (9704, 1577)	0.19396767072619994
#   (9704, 1587)	0.2464146613038757
#   (9704, 1719)	0.36817631783848603
#   (9704, 2185)	0.32079578634306527
#   (9704, 3506)	0.4238960555258595
#   (9705, 627)	0.4068025567228228
#   (9705, 634)	0.5434915776286265
#   (9705, 1421)	0.14049293254315742
#   (9705, 1452)	0.2191657016462286
#   (9705, 1655)	0.6865542338503651
#   (9706, 637)	0.34494223012020914
#   (9706, 638)	0.3948053687898757
#   (9706, 662)	0.14328086539063598
#   (9706, 664)	0.3203161733851467
#   (9706, 758)	0.2022535919597604
#   (9706, 767)	0.3327028080951646
#   (9706, 787)	0.4507653895205509
#   (9706, 1320)	0.3195317419878507
#   (9706, 1397)	0.3809515413182581
#   (9707, 343)	0.35026625098055275
#   (9707, 347)	0.41474087039913693
#   (9707, 745)	0.5942633926816786
#   (9707, 1172)	0.13161933281773605
#   (9707, 1189)	0.20929908157290342
#   (9707, 2861)	0.5394671719802873

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
def recomendar_filmes(titulo_filme, movies_df, cosine_sim_matrix, n_recomendacoes=10):
    print(f'gerando recomendações para filme {titulo_filme}\n')
    indices = pd.Series(movies_df.index, index=movies_df['titulo_movie_lens']).drop_duplicates()
    
    if titulo_filme not in indices:
        print(f"Filme '{titulo_filme}' não encontrado no dataset.")
        return pd.Series([])

    idx = indices[titulo_filme]

    sim_scores = list(enumerate(cosine_sim_matrix[idx]))



    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:n_recomendacoes + 1]  

    filme_indices = [i[0] for i in sim_scores]
    print(f"filmes similares ao {titulo_filme}")
    print(movies_df['titulo_movie_lens'].iloc[filme_indices].to_string(index=False))
    return movies_df['titulo_movie_lens'].iloc[filme_indices]



filme = "Toy Story (1995)"
recomendados = recomendar_filmes(filme, movies_tags, cosine_sim)
# Out:
# gerando recomendações para filme Toy Story (1995)
#
# filmes similares ao Toy Story (1995)
#             Toy Story 2 (1999)
#           Bug's Life, A (1998)
#             Toy Story 3 (2010)
#                   Balto (1995)
#                    Antz (1998)
#                   Moana (2016)
#               Wild, The (2006)
# Tale of Despereaux, The (2008)
#                      Up (2009)
#          Monsters, Inc. (2001)
